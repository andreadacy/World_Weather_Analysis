# %%
 from citipy import citipy
import numpy as np
import pandas as pd

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
 # Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 295.91,
#   'feels_like': 295.63,
#   'temp_min': 292.06,
#   'temp_max': 298.25,
#   'pressure': 1025,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 4.12, 'deg': 200},
#  'clouds': {'all': 33},
#  'dt': 1657486199,
#  'sys': {'type': 2,
#   'id': 268730,
#   'country': 'GB',
#   'sunrise': 1657425304,
#   'sunset': 1657484172},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | harper
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | kasongo-lunda
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | nagato
# Processing Record 13 of Set 1 | paamiut
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | rock sound
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | port hedland
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 1 | sorland
# Processing Record 24 of Set 1 | basoko
# Processing Record 25 of Set 1 | grindavik
# Processing Record 26 of Set 1 | vao
# Processing Record 27 of Set 1 | saint-pierre
# Processing Record 28 of Set 1 | tabou
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 1 | la rioja
# Processing Record 32 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 1 | morant bay
# Processing Record 34 of Set 1 | dillon
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | pryshyb
# Processing Record 37 of Set 1 | jeremie
# Processing Record 38 of Set 1 | inirida
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | pontianak
# Processing Record 41 of Set 1 | mezen
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | aleksandrovsk-sakhalinskiy
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | baker city
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | walvis bay
# Processing Record 50 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | koupela
# Processing Record 9 of Set 2 | chara
# Processing Record 10 of Set 2 | rawson
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | kupang
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | turukhansk
# Processing Record 17 of Set 2 | khromtau
# Processing Record 18 of Set 2 | ouesso
# Processing Record 19 of Set 2 | asyut
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | makakilo city
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | vestmanna
# Processing Record 24 of Set 2 | manuk mangkaw
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | mecca
# Processing Record 27 of Set 2 | ventspils
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | hobyo
# Processing Record 30 of Set 2 | guerrero negro
# Processing Record 31 of Set 2 | edosaki
# Processing Record 32 of Set 2 | sao gabriel da cachoeira
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | los llanos de aridane
# Processing Record 36 of Set 2 | la ronge
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 39 of Set 2 | jizan
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | port-gentil
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | znamenskoye
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | clarence town
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | bilma
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | lakes entrance
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | edson
# Processing Record 5 of Set 3 | coracora
# Processing Record 6 of Set 3 | san luis
# Processing Record 7 of Set 3 | falmouth
# Processing Record 8 of Set 3 | cascavel
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | henderson
# Processing Record 11 of Set 3 | karatuzskoye
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | uribia
# Processing Record 14 of Set 3 | chichi
# Processing Record 15 of Set 3 | kurikka
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | alingsas
# Processing Record 18 of Set 3 | krasnoselkup
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | jalu
# Processing Record 21 of Set 3 | gat
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | nkowakowa
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | rindal
# Processing Record 30 of Set 3 | we
# City not found. Skipping...
# Processing Record 31 of Set 3 | guayaramerin
# Processing Record 32 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | calama
# Processing Record 37 of Set 3 | monte santo de minas
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | punta arenas
# Processing Record 42 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 3 | cockburn town
# Processing Record 44 of Set 3 | fukuma
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | villa bruzual
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | killybegs
# Processing Record 1 of Set 4 | ngunguru
# Processing Record 2 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 3 of Set 4 | westport
# Processing Record 4 of Set 4 | lahat
# Processing Record 5 of Set 4 | van wert
# Processing Record 6 of Set 4 | uzhur-4
# City not found. Skipping...
# Processing Record 7 of Set 4 | moose factory
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | eenhana
# Processing Record 11 of Set 4 | jedburgh
# Processing Record 12 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | nusaybin
# Processing Record 15 of Set 4 | masaka
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | verkhnyaya sysert
# Processing Record 18 of Set 4 | oktyabrskiy
# Processing Record 19 of Set 4 | rudnaya pristan
# Processing Record 20 of Set 4 | rebrikha
# Processing Record 21 of Set 4 | soe
# Processing Record 22 of Set 4 | yoichi
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | vanimo
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | necochea
# Processing Record 29 of Set 4 | manzhouli
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | pimentel
# Processing Record 32 of Set 4 | takoradi
# Processing Record 33 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 4 | sangrur
# Processing Record 35 of Set 4 | port lincoln
# Processing Record 36 of Set 4 | avera
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | chardara
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | poum
# Processing Record 41 of Set 4 | springfield
# Processing Record 42 of Set 4 | iberia
# Processing Record 43 of Set 4 | qaqortoq
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | tiarei
# Processing Record 46 of Set 4 | camp verde
# Processing Record 47 of Set 4 | meulaboh
# Processing Record 48 of Set 4 | tucurui
# Processing Record 49 of Set 4 | carnaiba
# Processing Record 50 of Set 4 | gamba
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 5 | castrovillari
# Processing Record 4 of Set 5 | ahipara
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | mayskiy
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | port hardy
# Processing Record 9 of Set 5 | dusti
# Processing Record 10 of Set 5 | cravo norte
# Processing Record 11 of Set 5 | belyy yar
# Processing Record 12 of Set 5 | vermilion
# Processing Record 13 of Set 5 | les cayes
# Processing Record 14 of Set 5 | zeya
# Processing Record 15 of Set 5 | barrow
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | nikolskoye
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | provost
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | lafia
# Processing Record 22 of Set 5 | wenzhou
# Processing Record 23 of Set 5 | abu samrah
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | celestun
# Processing Record 26 of Set 5 | iqaluit
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | gimli
# Processing Record 29 of Set 5 | bluff
# Processing Record 30 of Set 5 | ucluelet
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | diphu
# Processing Record 33 of Set 5 | baykit
# Processing Record 34 of Set 5 | bell ville
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | mount isa
# Processing Record 37 of Set 5 | sao miguel do araguaia
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | shambu
# Processing Record 40 of Set 5 | mackenzie
# Processing Record 41 of Set 5 | visby
# Processing Record 42 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 5 | tuatapere
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | faya
# Processing Record 48 of Set 5 | renqiu
# Processing Record 49 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 50 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 6 | bara
# Processing Record 2 of Set 6 | victoria
# Processing Record 3 of Set 6 | port elizabeth
# Processing Record 4 of Set 6 | luwuk
# Processing Record 5 of Set 6 | sovkhoznyy
# Processing Record 6 of Set 6 | mantua
# Processing Record 7 of Set 6 | riyadh
# Processing Record 8 of Set 6 | nanyuki
# Processing Record 9 of Set 6 | nizhniy baskunchak
# Processing Record 10 of Set 6 | ancud
# Processing Record 11 of Set 6 | hvide sande
# Processing Record 12 of Set 6 | lasa
# Processing Record 13 of Set 6 | broken hill
# Processing Record 14 of Set 6 | poya
# Processing Record 15 of Set 6 | daru
# Processing Record 16 of Set 6 | ranau
# Processing Record 17 of Set 6 | banda aceh
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | ahuimanu
# Processing Record 21 of Set 6 | jeremoabo
# Processing Record 22 of Set 6 | mahbubnagar
# Processing Record 23 of Set 6 | imbituba
# Processing Record 24 of Set 6 | ust-barguzin
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | chihuahua
# Processing Record 27 of Set 6 | xai-xai
# Processing Record 28 of Set 6 | tobermory
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | shalinskoye
# Processing Record 31 of Set 6 | shingu
# Processing Record 32 of Set 6 | horasan
# Processing Record 33 of Set 6 | leningradskiy
# Processing Record 34 of Set 6 | hudson bay
# Processing Record 35 of Set 6 | ca mau
# Processing Record 36 of Set 6 | cortez
# Processing Record 37 of Set 6 | tatarsk
# Processing Record 38 of Set 6 | tocopilla
# Processing Record 39 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 6 | karlskrona
# Processing Record 41 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 6 | matara
# Processing Record 43 of Set 6 | aksha
# Processing Record 44 of Set 6 | provideniya
# Processing Record 45 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 6 | ramnagar
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | panuco
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | sao jose da coroa grande
# Processing Record 2 of Set 7 | sao filipe
# Processing Record 3 of Set 7 | constitucion
# Processing Record 4 of Set 7 | hamadan
# Processing Record 5 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | santa vitoria do palmar
# Processing Record 8 of Set 7 | dalby
# Processing Record 9 of Set 7 | cap malheureux
# Processing Record 10 of Set 7 | coihaique
# Processing Record 11 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | mbandaka
# Processing Record 15 of Set 7 | palmer
# Processing Record 16 of Set 7 | evensk
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | kattivakkam
# Processing Record 19 of Set 7 | aklavik
# Processing Record 20 of Set 7 | atar
# Processing Record 21 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | ridgecrest
# Processing Record 24 of Set 7 | barreirinha
# Processing Record 25 of Set 7 | havoysund
# Processing Record 26 of Set 7 | hovd
# Processing Record 27 of Set 7 | kautokeino
# Processing Record 28 of Set 7 | urumqi
# Processing Record 29 of Set 7 | lebu
# Processing Record 30 of Set 7 | tripoli
# Processing Record 31 of Set 7 | hofn
# Processing Record 32 of Set 7 | pacific grove
# Processing Record 33 of Set 7 | seoul
# Processing Record 34 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 7 | asau
# Processing Record 36 of Set 7 | berlevag
# Processing Record 37 of Set 7 | cherskiy
# Processing Record 38 of Set 7 | mareeba
# Processing Record 39 of Set 7 | guarapari
# Processing Record 40 of Set 7 | verkhnyaya inta
# Processing Record 41 of Set 7 | ayan
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 7 | porto walter
# Processing Record 45 of Set 7 | diu
# Processing Record 46 of Set 7 | novochernorechenskiy
# Processing Record 47 of Set 7 | opuwo
# Processing Record 48 of Set 7 | teahupoo
# Processing Record 49 of Set 7 | fare
# Processing Record 50 of Set 7 | nizwa
# Processing Record 1 of Set 8 | langsa
# Processing Record 2 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 3 of Set 8 | danielskuil
# Processing Record 4 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 8 | morro bay
# Processing Record 6 of Set 8 | santiago
# Processing Record 7 of Set 8 | ipixuna
# Processing Record 8 of Set 8 | inta
# Processing Record 9 of Set 8 | warri
# Processing Record 10 of Set 8 | clyde river
# Processing Record 11 of Set 8 | richards bay
# Processing Record 12 of Set 8 | kalangala
# Processing Record 13 of Set 8 | sambava
# Processing Record 14 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 8 | samana
# Processing Record 16 of Set 8 | grenfell
# Processing Record 17 of Set 8 | puerto escondido
# Processing Record 18 of Set 8 | nelson bay
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | saskylakh
# Processing Record 21 of Set 8 | nara
# Processing Record 22 of Set 8 | torbay
# Processing Record 23 of Set 8 | victor harbor
# Processing Record 24 of Set 8 | bandarbeyla
# Processing Record 25 of Set 8 | vaulx-en-velin
# Processing Record 26 of Set 8 | buenaventura
# Processing Record 27 of Set 8 | qesarya
# Processing Record 28 of Set 8 | asnaes
# Processing Record 29 of Set 8 | governador dix-sept rosado
# Processing Record 30 of Set 8 | san andres
# Processing Record 31 of Set 8 | ramon
# Processing Record 32 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 8 | loutra
# Processing Record 34 of Set 8 | asosa
# Processing Record 35 of Set 8 | nishihara
# Processing Record 36 of Set 8 | grand bank
# Processing Record 37 of Set 8 | samarai
# Processing Record 38 of Set 8 | yambio
# Processing Record 39 of Set 8 | arlit
# Processing Record 40 of Set 8 | mitu
# Processing Record 41 of Set 8 | alice springs
# Processing Record 42 of Set 8 | shar
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | kampong thum
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | rocha
# Processing Record 47 of Set 8 | caravelas
# Processing Record 48 of Set 8 | parabel
# Processing Record 49 of Set 8 | wewak
# Processing Record 50 of Set 8 | ampanihy
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | kargopol
# Processing Record 3 of Set 9 | kruisfontein
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | gorazde
# Processing Record 6 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 9 | carnduff
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | flinders
# Processing Record 10 of Set 9 | caribou
# Processing Record 11 of Set 9 | coahuayana
# Processing Record 12 of Set 9 | amparafaravola
# Processing Record 13 of Set 9 | salinas
# Processing Record 14 of Set 9 | madimba
# Processing Record 15 of Set 9 | toora-khem
# Processing Record 16 of Set 9 | tumbagaan
# Processing Record 17 of Set 9 | kovdor
# Processing Record 18 of Set 9 | rosetta
# Processing Record 19 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 9 | solnechnyy
# Processing Record 21 of Set 9 | doka
# Processing Record 22 of Set 9 | rengo
# Processing Record 23 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 24 of Set 9 | chinhoyi
# Processing Record 25 of Set 9 | honiara
# Processing Record 26 of Set 9 | kasongo
# Processing Record 27 of Set 9 | canon city
# Processing Record 28 of Set 9 | isla vista
# Processing Record 29 of Set 9 | pombia
# Processing Record 30 of Set 9 | colares
# Processing Record 31 of Set 9 | guamuchil
# Processing Record 32 of Set 9 | chicama
# Processing Record 33 of Set 9 | santa cruz de tenerife
# Processing Record 34 of Set 9 | port augusta
# Processing Record 35 of Set 9 | naze
# Processing Record 36 of Set 9 | kashi
# Processing Record 37 of Set 9 | chiknayakanhalli
# Processing Record 38 of Set 9 | guipavas
# Processing Record 39 of Set 9 | dong hoi
# Processing Record 40 of Set 9 | neryungri
# Processing Record 41 of Set 9 | pionerskiy
# Processing Record 42 of Set 9 | chupa
# Processing Record 43 of Set 9 | huesca
# Processing Record 44 of Set 9 | udachnyy
# Processing Record 45 of Set 9 | fort nelson
# Processing Record 46 of Set 9 | santa rosa
# Processing Record 47 of Set 9 | great yarmouth
# Processing Record 48 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 9 | porto novo
# Processing Record 50 of Set 9 | maniitsoq
# Processing Record 1 of Set 10 | qujing
# Processing Record 2 of Set 10 | zlobin
# Processing Record 3 of Set 10 | winnemucca
# Processing Record 4 of Set 10 | marysville
# Processing Record 5 of Set 10 | west wendover
# Processing Record 6 of Set 10 | namibe
# Processing Record 7 of Set 10 | nizhniy tsasuchey
# Processing Record 8 of Set 10 | greensburg
# Processing Record 9 of Set 10 | isangel
# Processing Record 10 of Set 10 | sisophon
# Processing Record 11 of Set 10 | havre
# Processing Record 12 of Set 10 | chabahar
# Processing Record 13 of Set 10 | lompoc
# Processing Record 14 of Set 10 | kondinskoye
# Processing Record 15 of Set 10 | innisfail
# Processing Record 16 of Set 10 | costinesti
# Processing Record 17 of Set 10 | chestermere
# Processing Record 18 of Set 10 | uyuni
# Processing Record 19 of Set 10 | knysna
# Processing Record 20 of Set 10 | dekernes
# Processing Record 21 of Set 10 | ormara
# Processing Record 22 of Set 10 | carballo
# Processing Record 23 of Set 10 | elko
# Processing Record 24 of Set 10 | russell
# Processing Record 25 of Set 10 | pokaran
# Processing Record 26 of Set 10 | wakkanai
# Processing Record 27 of Set 10 | merauke
# Processing Record 28 of Set 10 | socorro
# Processing Record 29 of Set 10 | joao pinheiro
# Processing Record 30 of Set 10 | chornukhy
# Processing Record 31 of Set 10 | bongandanga
# Processing Record 32 of Set 10 | half moon bay
# Processing Record 33 of Set 10 | kabin buri
# Processing Record 34 of Set 10 | kisesa
# Processing Record 35 of Set 10 | damietta
# Processing Record 36 of Set 10 | keita
# Processing Record 37 of Set 10 | marquette
# Processing Record 38 of Set 10 | chapais
# Processing Record 39 of Set 10 | xichang
# Processing Record 40 of Set 10 | belgrade
# Processing Record 41 of Set 10 | balteni
# Processing Record 42 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 45 of Set 10 | imisli
# City not found. Skipping...
# Processing Record 46 of Set 10 | bud
# Processing Record 47 of Set 10 | bahia blanca
# Processing Record 48 of Set 10 | talakan
# Processing Record 49 of Set 10 | skibbereen
# Processing Record 50 of Set 10 | bethel
# Processing Record 1 of Set 11 | teya
# Processing Record 2 of Set 11 | college
# Processing Record 3 of Set 11 | dhidhdhoo
# Processing Record 4 of Set 11 | svetlogorsk
# Processing Record 5 of Set 11 | havelock
# Processing Record 6 of Set 11 | livramento
# Processing Record 7 of Set 11 | maputo
# Processing Record 8 of Set 11 | maceio
# Processing Record 9 of Set 11 | fairbanks
# Processing Record 10 of Set 11 | san pedro buenavista
# Processing Record 11 of Set 11 | mayumba
# Processing Record 12 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 11 | erzin
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | gisborne
# Processing Record 16 of Set 11 | ambilobe
# Processing Record 17 of Set 11 | vigrestad
# Processing Record 18 of Set 11 | kysyl-syr
# Processing Record 19 of Set 11 | alofi
# Processing Record 20 of Set 11 | fallon
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 11 | narasannapeta
# Processing Record 25 of Set 11 | krasnoarmeysk
# Processing Record 26 of Set 11 | burnie
# Processing Record 27 of Set 11 | katsuura
# Processing Record 28 of Set 11 | alta floresta
# Processing Record 29 of Set 11 | kryvyy rih
# Processing Record 30 of Set 11 | san jose del guaviare
# Processing Record 31 of Set 11 | kleck
# City not found. Skipping...
# Processing Record 32 of Set 11 | eugene
# Processing Record 33 of Set 11 | batagay-alyta
# Processing Record 34 of Set 11 | dunedin
# Processing Record 35 of Set 11 | starodub
# Processing Record 36 of Set 11 | antequera
# Processing Record 37 of Set 11 | great malvern
# Processing Record 38 of Set 11 | quarteira
# Processing Record 39 of Set 11 | antalaha
# Processing Record 40 of Set 11 | sabang
# Processing Record 41 of Set 11 | bosobolo
# Processing Record 42 of Set 11 | banyo
# Processing Record 43 of Set 11 | deputatskiy
# Processing Record 44 of Set 11 | amravati
# Processing Record 45 of Set 11 | uyemskiy
# Processing Record 46 of Set 11 | tonj
# Processing Record 47 of Set 11 | sur
# Processing Record 48 of Set 11 | iracoubo
# Processing Record 49 of Set 11 | tromso
# Processing Record 50 of Set 11 | martapura
# Processing Record 1 of Set 12 | villamontes
# Processing Record 2 of Set 12 | pachperwa
# Processing Record 3 of Set 12 | seryshevo
# Processing Record 4 of Set 12 | lamu
# Processing Record 5 of Set 12 | ndele
# Processing Record 6 of Set 12 | lata
# Processing Record 7 of Set 12 | seydi
# Processing Record 8 of Set 12 | zemetchino
# Processing Record 9 of Set 12 | correntina
# Processing Record 10 of Set 12 | krasne
# Processing Record 11 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 12 | maragogi
# Processing Record 13 of Set 12 | luang prabang
# Processing Record 14 of Set 12 | olafsvik
# Processing Record 15 of Set 12 | banovce
# City not found. Skipping...
# Processing Record 16 of Set 12 | rionegro
# Processing Record 17 of Set 12 | tucumcari
# Processing Record 18 of Set 12 | mehamn
# Processing Record 19 of Set 12 | buala
# Processing Record 20 of Set 12 | dongfeng
# Processing Record 21 of Set 12 | ciudad bolivar
# Processing Record 22 of Set 12 | antofagasta
# Processing Record 23 of Set 12 | presidencia roque saenz pena
# Processing Record 24 of Set 12 | salmas
# Processing Record 25 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 12 | barra do bugres
# Processing Record 27 of Set 12 | tekeli
# Processing Record 28 of Set 12 | yekepa
# Processing Record 29 of Set 12 | tiznit
# Processing Record 30 of Set 12 | isiro
# Processing Record 31 of Set 12 | sayyan
# Processing Record 32 of Set 12 | raudeberg
# Processing Record 33 of Set 12 | kalmunai
# Processing Record 34 of Set 12 | codrington
# Processing Record 35 of Set 12 | tres lagoas
# Processing Record 36 of Set 12 | biak
# Processing Record 37 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 12 | abu zabad
# Processing Record 39 of Set 12 | tura
# Processing Record 40 of Set 12 | vardo
# Processing Record 41 of Set 12 | vysokogornyy
# Processing Record 42 of Set 12 | cascioarele
# Processing Record 43 of Set 12 | buchanan
# Processing Record 44 of Set 12 | yining
# Processing Record 45 of Set 12 | port hawkesbury
# Processing Record 46 of Set 12 | iskateley
# Processing Record 47 of Set 12 | kimbe
# Processing Record 48 of Set 12 | noyabrsk
# Processing Record 49 of Set 12 | rayong
# Processing Record 50 of Set 12 | tilichiki
# Processing Record 1 of Set 13 | maxixe
# Processing Record 2 of Set 13 | nome
# Processing Record 3 of Set 13 | obidos
# Processing Record 4 of Set 13 | henties bay
# Processing Record 5 of Set 13 | camacha
# Processing Record 6 of Set 13 | bone
# Processing Record 7 of Set 13 | isawa
# Processing Record 8 of Set 13 | lahij
# Processing Record 9 of Set 13 | sala consilina
# Processing Record 10 of Set 13 | ylivieska
# Processing Record 11 of Set 13 | kavaratti
# Processing Record 12 of Set 13 | jiuquan
# Processing Record 13 of Set 13 | lagoa
# Processing Record 14 of Set 13 | svetla nad sazavou
# Processing Record 15 of Set 13 | hirara
# Processing Record 16 of Set 13 | valparaiso
# Processing Record 17 of Set 13 | beidao
# Processing Record 18 of Set 13 | tommot
# Processing Record 19 of Set 13 | chilca
# Processing Record 20 of Set 13 | ostrovnoy
# Processing Record 21 of Set 13 | kieta
# Processing Record 22 of Set 13 | arona
# Processing Record 23 of Set 13 | yumen
# Processing Record 24 of Set 13 | tongren
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | matiguas
# Processing Record 27 of Set 13 | karasburg
# Processing Record 28 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 13 | chumikan
# Processing Record 30 of Set 13 | bonthe
# Processing Record 31 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 13 | sept-iles
# Processing Record 34 of Set 13 | zhanaozen
# Processing Record 35 of Set 13 | marawi
# Processing Record 36 of Set 13 | barra do garcas
# Processing Record 37 of Set 13 | eirunepe
# Processing Record 38 of Set 13 | lokosovo
# Processing Record 39 of Set 13 | san juan
# Processing Record 40 of Set 13 | marsh harbour
# Processing Record 41 of Set 13 | srednekolymsk
# Processing Record 42 of Set 13 | coldwater
# Processing Record 43 of Set 13 | tumaco
# Processing Record 44 of Set 13 | blagoveshchenka
# Processing Record 45 of Set 13 | sinnamary
# Processing Record 46 of Set 13 | honningsvag
# Processing Record 47 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 13 | trelew
# Processing Record 49 of Set 13 | zabid
# Processing Record 50 of Set 13 | uige
# Processing Record 1 of Set 14 | zhangye
# Processing Record 2 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 14 | scarborough
# Processing Record 4 of Set 14 | usinsk
# Processing Record 5 of Set 14 | broome
# Processing Record 6 of Set 14 | rivera
# Processing Record 7 of Set 14 | mayo
# Processing Record 8 of Set 14 | progreso
# Processing Record 9 of Set 14 | baruun-urt
# Processing Record 10 of Set 14 | trang
# Processing Record 11 of Set 14 | bagan
# Processing Record 12 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 14 | saint-paul
# Processing Record 14 of Set 14 | yaring
# Processing Record 15 of Set 14 | petauke
# Processing Record 16 of Set 14 | el coyote
# Processing Record 17 of Set 14 | hollola
# Processing Record 18 of Set 14 | jinchang
# Processing Record 19 of Set 14 | tomohon
# Processing Record 20 of Set 14 | shimoda
# Processing Record 21 of Set 14 | bellary
# Processing Record 22 of Set 14 | hibbing
# Processing Record 23 of Set 14 | san francisco
# Processing Record 24 of Set 14 | massakory
# Processing Record 25 of Set 14 | harindanga
# Processing Record 26 of Set 14 | tambovka
# Processing Record 27 of Set 14 | qasigiannguit
# Processing Record 28 of Set 14 | vung tau
# Processing Record 29 of Set 14 | ribeira brava
# Processing Record 30 of Set 14 | kaitangata
# Processing Record 31 of Set 14 | cururupu
# Processing Record 32 of Set 14 | tanout
# Processing Record 33 of Set 14 | santa isabel do rio negro
# Processing Record 34 of Set 14 | palembang
# Processing Record 35 of Set 14 | tutoia
# Processing Record 36 of Set 14 | aykhal
# Processing Record 37 of Set 14 | salinopolis
# Processing Record 38 of Set 14 | ust-maya
# Processing Record 39 of Set 14 | georgiyevskoye
# Processing Record 40 of Set 14 | sakakah
# Processing Record 41 of Set 14 | tual
# Processing Record 42 of Set 14 | boueni
# Processing Record 43 of Set 14 | lodja
# Processing Record 44 of Set 14 | kotelnich
# Processing Record 45 of Set 14 | muravlenko
# Processing Record 46 of Set 14 | taoudenni
# Processing Record 47 of Set 14 | manzanillo
# Processing Record 48 of Set 14 | dukat
# Processing Record 49 of Set 14 | bozhou
# Processing Record 50 of Set 14 | muncar
# Processing Record 1 of Set 15 | tunceli
# Processing Record 2 of Set 15 | hualmay
# Processing Record 3 of Set 15 | omboue
# Processing Record 4 of Set 15 | kaputa
# Processing Record 5 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 15 | novaya zaimka
# Processing Record 7 of Set 15 | arman
# Processing Record 8 of Set 15 | le port
# Processing Record 9 of Set 15 | ulladulla
# Processing Record 10 of Set 15 | alice town
# Processing Record 11 of Set 15 | darjiling
# Processing Record 12 of Set 15 | uddevalla
# Processing Record 13 of Set 15 | goderich
# Processing Record 14 of Set 15 | pokrovskoye
# Processing Record 15 of Set 15 | mandalgovi
# Processing Record 16 of Set 15 | boa vista
# Processing Record 17 of Set 15 | hua hin
# Processing Record 18 of Set 15 | salta
# Processing Record 19 of Set 15 | mogadishu
# Processing Record 20 of Set 15 | skiros
# City not found. Skipping...
# Processing Record 21 of Set 15 | mattru
# Processing Record 22 of Set 15 | ixtapa
# Processing Record 23 of Set 15 | los algarrobos
# Processing Record 24 of Set 15 | mana
# Processing Record 25 of Set 15 | chegdomyn
# Processing Record 26 of Set 15 | deniliquin
# Processing Record 27 of Set 15 | umm lajj
# Processing Record 28 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 15 | vieste
# Processing Record 30 of Set 15 | champerico
# Processing Record 31 of Set 15 | spasskoye
# Processing Record 32 of Set 15 | altusried
# Processing Record 33 of Set 15 | pasni
# Processing Record 34 of Set 15 | mombetsu
# Processing Record 35 of Set 15 | beruni
# City not found. Skipping...
# Processing Record 36 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 15 | marratxi
# Processing Record 39 of Set 15 | raisinghnagar
# Processing Record 40 of Set 15 | ongandjera
# Processing Record 41 of Set 15 | arrifes
# Processing Record 42 of Set 15 | glencoe
# Processing Record 43 of Set 15 | galle
# Processing Record 44 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 15 | kraksaan
# Processing Record 46 of Set 15 | kurim
# Processing Record 47 of Set 15 | tottori
# Processing Record 48 of Set 15 | gazalkent
# Processing Record 49 of Set 15 | jieshi
# Processing Record 50 of Set 15 | diamantino
# Processing Record 1 of Set 16 | dzilam gonzalez
# Processing Record 2 of Set 16 | san cristobal
# Processing Record 3 of Set 16 | puro
# Processing Record 4 of Set 16 | kemin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0      Hithadhoo  -0.6000   73.0833     82.36     overcast clouds        71
# 1        Rikitea -23.1203 -134.9692     72.77          few clouds        78
# 2         Harper   4.3750   -7.7169     75.25          few clouds        77
# 3        Fortuna  40.5982 -124.1573     72.93           clear sky        72
# 4      Esperance -33.8667  121.9000     54.59       broken clouds        77
# 5  Kasongo-Lunda  -6.4667   16.8167     71.26          few clouds        37
# 6      Jamestown  42.0970  -79.2353     82.06           clear sky        30
# 7         Atuona  -9.8000 -139.0333     77.20       broken clouds        79
# 8         Castro -24.7911  -50.0119     59.63           clear sky        74
# 9          Vaini -21.2000 -175.2000     75.51       broken clouds        81
#
#    Cloudiness  Wind Speed Country
# 0         100        4.03      MV
# 1          17        4.21      PF
# 2          22        7.94      LR
# 3           0        5.01      US
# 4          83        8.81      AU
# 5          11        0.76      CD
# 6           0        5.75      US
# 7          54       18.59      PF
# 8           6        3.47      BR
# 9          75       23.42      TO

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hithadhoo      MV  -0.6000   73.0833     82.36        71         100
# 1        Rikitea      PF -23.1203 -134.9692     72.77        78          17
# 2         Harper      LR   4.3750   -7.7169     75.25        77          22
# 3        Fortuna      US  40.5982 -124.1573     72.93        72           0
# 4      Esperance      AU -33.8667  121.9000     54.59        77          83
# 5  Kasongo-Lunda      CD  -6.4667   16.8167     71.26        37          11
# 6      Jamestown      US  42.0970  -79.2353     82.06        30           0
# 7         Atuona      PF  -9.8000 -139.0333     77.20        79          54
# 8         Castro      BR -24.7911  -50.0119     59.63        74           6
# 9          Vaini      TO -21.2000 -175.2000     75.51        81          75
#
#    Wind Speed Current Description
# 0        4.03     overcast clouds
# 1        4.21          few clouds
# 2        7.94          few clouds
# 3        5.01           clear sky
# 4        8.81       broken clouds
# 5        0.76          few clouds
# 6        5.75           clear sky
# 7       18.59       broken clouds
# 8        3.47           clear sky
# 9       23.42       broken clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "../WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
